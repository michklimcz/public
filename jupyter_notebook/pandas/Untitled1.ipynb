# %%
import pandas as pd

# %%
df = pd.read_csv('olympics.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df[['City','Year']]
# Out:
#                   City  Year
# 0            Barcelona  1992
# 1               London  2012
# 2            Antwerpen  1920
# 3                Paris  1900
# 4              Calgary  1988
# ...                ...   ...
# 271111       Innsbruck  1976
# 271112           Sochi  2014
# 271113           Sochi  2014
# 271114          Nagano  1998
# 271115  Salt Lake City  2002
#
# [271116 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.NOC
# Out:
# 0         CHN
# 1         CHN
# 2         DEN
# 3         DEN
# 4         NED
#          ...
# 271111    POL
# 271112    POL
# 271113    POL
# 271114    POL
# 271115    POL
# Name: NOC, Length: 271116, dtype: object

# %%
type(df.NOC)
# Out:
# pandas.core.series.Series

# %%
type(df['NOC'])
# Out:
# pandas.core.series.Series

# %%
df[['NOC','Sex']]
# Out:
#         NOC Sex
# 0       CHN   M
# 1       CHN   M
# 2       DEN   M
# 3       DEN   M
# 4       NED   F
# ...     ...  ..
# 271111  POL   M
# 271112  POL   M
# 271113  POL   M
# 271114  POL   M
# 271115  POL   M
#
# [271116 rows x 2 columns]

# %%
type(df[['Sex','NOC']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.shape[0]
# Out:
# 271116

# %%
df.shape[1]
# Out:
# 15

# %%
df.head(100)
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ..  ..                                 ...  ..   ...     ...     ...
# 95  32                Olav Augunson Aarnes   M  23.0     NaN     NaN
# 96  33                 Mika Lauri Aarnikka   M  24.0   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M  28.0   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M  24.0   190.0    98.0
#
#               Team  NOC        Games  Year  Season       City          Sport  \
# ...

# %%
df.tail(100)
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 271016  135523  Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271017  135524          Nicolaus "Nic" Zwetnow   M  31.0   181.0    70.0
# 271018  135524          Nicolaus "Nic" Zwetnow   M  35.0   181.0    70.0
# 271019  135525                  Martin Zwicker   M  29.0   175.0    64.0
# 271020  135526                    Dniel Zwickl   M  27.0   178.0    71.0
# ...        ...                             ...  ..   ...     ...     ...
# 271111  135569                      Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                        Piotr ya   M  27.0   176.0    59.0
# 271113  135570                        Piotr ya   M  27.0   176.0    59.0
# 271114  135571              Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571              Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
df.Sex.value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
df.Sport.value_counts(ascending=False)
# Out:
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: Sport, Length: 66, dtype: int64

# %%
df.Sport.sort_values()
# Out:
# 214105      Aeronautics
# 59184     Alpine Skiing
# 216145    Alpine Skiing
# 216144    Alpine Skiing
# 15326     Alpine Skiing
#               ...
# 115174        Wrestling
# 43200         Wrestling
# 115161        Wrestling
# 73860         Wrestling
# 7080          Wrestling
# Name: Sport, Length: 271116, dtype: object

# %%
df.sort_values(by=['Sex','Sport'])
# Out:
#             ID                 Name Sex   Age  Height  Weight            Team  \
# 252        126       Forough Abbasi   F  20.0   164.0    58.0            Iran
# 743        426  Edme Abetel (-Barr)   F  29.0     NaN     NaN     Switzerland
# 808        462            Ilze bola   F  19.0   169.0    60.0          Latvia
# 809        463        Agnese boltia   F  17.0   166.0    60.0          Latvia
# 810        463        Agnese boltia   F  17.0   166.0    60.0          Latvia
# ...        ...                  ...  ..   ...     ...     ...             ...
# 270954  135493        Edward uawnik   M  27.0   165.0    73.0          Poland
# 270962  135499    Alberts Zvejnieks   M  25.0     NaN     NaN          Latvia
# 270963  135499    Alberts Zvejnieks   M  33.0     NaN     NaN          Latvia
# 270983  135505    Armands Zvirbulis   M  24.0   177.0    84.0          Latvia
# 270985  135507          Karel Zvona   M  23.0     NaN     NaN  Czechoslovakia
#
# ...

# %%
df.Medal=='Gold'
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Medal, Length: 271116, dtype: bool

# %%
df[(df.Medal=='Gold')|(df.Medal=='Silver')|(df.Medal=='Bronze')]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
df[df.Sport.str.contains('Skiing')]
# Out:
#             ID                 Name Sex   Age  Height  Weight           Team  \
# 10           6      Per Knut Aaland   M  31.0   188.0    75.0  United States
# 11           6      Per Knut Aaland   M  31.0   188.0    75.0  United States
# 12           6      Per Knut Aaland   M  31.0   188.0    75.0  United States
# 13           6      Per Knut Aaland   M  31.0   188.0    75.0  United States
# 14           6      Per Knut Aaland   M  33.0   188.0    75.0  United States
# ...        ...                  ...  ..   ...     ...     ...            ...
# 271070  135551  Vladislavas Zybaila   M  27.0   178.0    75.0      Lithuania
# 271071  135551  Vladislavas Zybaila   M  27.0   178.0    75.0      Lithuania
# 271072  135551  Vladislavas Zybaila   M  27.0   178.0    75.0      Lithuania
# 271073  135551  Vladislavas Zybaila   M  27.0   178.0    75.0      Lithuania
# 271074  135551  Vladislavas Zybaila   M  27.0   178.0    75.0      Lithuania
#
# ...

# %%
df[df.Name.str.contains('Kowalski')]
# Out:
#            ID                         Name Sex   Age  Height  Weight  \
# 125929  63518                Adam Kowalski   M  19.0   176.0    72.0
# 125930  63518                Adam Kowalski   M  23.0   176.0    72.0
# 125931  63518                Adam Kowalski   M  35.0   176.0    72.0
# 125932  63519          Aleksander Kowalski   M  25.0     NaN     NaN
# 125933  63520    Aleksander Marek Kowalski   M  25.0   189.0    78.0
# 125934  63520    Aleksander Marek Kowalski   M  29.0   189.0    78.0
# 125935  63521       Daniel Steven Kowalski   M  21.0   180.0    76.0
# 125936  63521       Daniel Steven Kowalski   M  21.0   180.0    76.0
# 125937  63521       Daniel Steven Kowalski   M  21.0   180.0    76.0
# 125938  63521       Daniel Steven Kowalski   M  21.0   180.0    76.0
# 125939  63521       Daniel Steven Kowalski   M  25.0   180.0    76.0
# 125940  63522       Jerzy Wadysaw Kowalski   M  23.0   175.0    70.0
# 125941  63522       Jerzy Wadysaw Kowalski   M  23.0   175.0    70.0
# ...

# %%
df.Name.str.contains('Kowalski').value_counts()
# Out:
# False    271099
# True         17
# Name: Name, dtype: int64

# %%
df.Year.value_counts().sort_index().plot(kind='bar',figsize=(16,7),title='Amount of phenomenoms in each year at olympicks')
# Out:
# <AxesSubplot:title={'center':'Amount of phenomenoms in each year at olympicks'}>

# %%
samochody = {'id':[1,2,3,4],
             "marka":['volvo','lamborgini','ww','peugeot'],
            "cena":[1200,100000,30000,1500],
            "garaz":[1,2,3,1]}
garaze = {'id':[1,2,3],
        'nazwa': ['garaz1','garaz2','garaz3']
}

# %%
dfsamochody=pd.DataFrame(samochody)
dfsamochody
dfgaraze=pd.DataFrame(garaze)
dfgaraze
# Out:
#    id   nazwa
# 0   1  garaz1
# 1   2  garaz2
# 2   3  garaz3

# %%
dfsamochody.set_index('id')
# Out:
#          marka    cena  garaz
# id
# 1        volvo    1200      1
# 2   lamborgini  100000      2
# 3           ww   30000      3
# 4      peugeot    1500      1

# %%
dfsamochody
# Out:
#    id       marka    cena  garaz
# 0   1       volvo    1200      1
# 1   2  lamborgini  100000      2
# 2   3          ww   30000      3
# 3   4     peugeot    1500      1

# %%
dfgaraze
# Out:
#    id   nazwa
# 0   1  garaz1
# 1   2  garaz2
# 2   3  garaz3

# %%
dfsamochody.join(dfgaraze.set_index('id'),on='id')
# Out:
#    id       marka    cena  garaz   nazwa
# 0   1       volvo    1200      1  garaz1
# 1   2  lamborgini  100000      2  garaz2
# 2   3          ww   30000      3  garaz3
# 3   4     peugeot    1500      1     NaN

# %%
df_math = pd.DataFrame([[4,9]]*3,columns=['A','B'])
df_math
# Out:
#    A  B
# 0  4  9
# 1  4  9
# 2  4  9

# %%
import numpy as np

# %%
df_math.apply(np.sqrt)
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %%
def add3(x):
    return x+3
df_math.apply(add3)
# Out:
#    A   B
# 0  7  12
# 1  7  12
# 2  7  12

# %%
df_math['B'] = df_math['B'].apply(add3)

# %%
df_math
# Out:
#    A   B
# 0  4  12
# 1  4  12
# 2  4  12

# %%
df_math2 = df.apply(lambda x:x/2+10)

# %%
df_math2
# Out:
#       A     B
# 0  12.0  14.5
# 1  12.0  14.5
# 2  12.0  14.5

# %%
print (df_math2['A'].aggregate(np.sum))
# Out:
# 36.0
